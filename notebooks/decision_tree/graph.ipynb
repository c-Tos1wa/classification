# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.inspection import DecisionBoundaryDisplay

# %%
iris = load_iris()

# %%
# parameters
n_classes = 3
plot_colors = "ybr"
plot_step = 0.05

# %%
for pairidx, pair in enumerate([[0,1], [0,2], [0,3], [1,2], [1,3], [2,3]]):
    X = iris.data[:, pair]
    Y = iris.target

    dtc = DecisionTreeClassifier().fit(X, Y)

    ax = plt.subplot(2, 3, pairidx + 1)
    plt.tight_layout(
        h_pad = 0.5,
        w_pad = 0.5,
        pad = 2.5
    )
    DecisionBoundaryDisplay.from_estimator(
        dtc,
        X,
        cmap = plt.cm.PiYG,
        response_method = "predict",
        ax = ax,
        xlabel = iris.feature_names[pair[0]],
        ylabel = iris.feature_names[pair[1]]
    )

    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where( Y == i )
        plt.scatter(
            X[idx, 0],
            X[idx, 1],
            c = color,
            label = iris.target_names[i],
            cmap = plt.cm.PiYG,
            edgecolor = "black",
            s = 15
        )
plt.suptitle("Decision Tree no conjunto de dados iris")
plt.legend(loc = "best", borderpad = 0, handletextpad = 0)
plt.show()
# Out:
# /tmp/ipykernel_15928/3269920817.py:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# /tmp/ipykernel_15928/3269920817.py:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# /tmp/ipykernel_15928/3269920817.py:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# /tmp/ipykernel_15928/3269920817.py:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# /tmp/ipykernel_15928/3269920817.py:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# /tmp/ipykernel_15928/3269920817.py:25: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
